# %%
import pandas as pd
import numpy as np
# !pwd
# Out:
# /Users/Lisa/_MLB_Prediction_capstone/data/Retrosheet_2010_2019

# %%
lst = "Date,DoubleHeader,DayOfWeek,VisitingTeam,VisitingTeamLeague,VisitingTeamGameNumber,HomeTeam,HomeTeamLeague,HomeTeamGameNumber,VisitorRunsScored,HomeRunsScore,LengthInOuts,DayNight,CompletionInfo,ForfeitInfo,ProtestInfo,ParkID,Attendence,Duration,VisitorLineScore,HomeLineScore,VisitorAB,VisitorH,VisitorD,VisitorT,VisitorHR,VisitorRBI,VisitorSH,VisitorSF,VisitorHBP,VisitorBB,VisitorIBB,VisitorK,VisitorSB,VisitorCS,VisitorGDP,VisitorCI,VisitorLOB,VisitorPitchers,VisitorER,VisitorTER,VisitorWP,VisitorBalks,VisitorPO,VisitorA,VisitorE,VisitorPassed,VisitorDB,VisitorTP,HomeAB,HomeH,HomeD,HomeT,HomeHR,HomeRBI,HomeSH,HomeSF,HomeHBP,HomeBB,HomeIBB,HomeK,HomeSB,HomeCS,HomeGDP,HomeCI,HomeLOB,HomePitchers,HomeER,HomeTER,HomeWP,HomeBalks,HomePO,HomeA,HomeE,HomePassed,HomeDB,HomeTP,UmpireHID,UmpireHName,Umpire1BID,Umpire1BName,Umpire2BID,Umpire2BName,Umpire3BID,Umpire3BName,UmpireLFID,UmpireLFName,UmpireRFID,UmpireRFName,VisitorManagerID,VisitorManagerName,HomeManagerID,HomeManagerName,WinningPitcherID,WinningPitcherName,LosingPitcherID,LosingPitcherNAme,SavingPitcherID,SavingPitcherName,GameWinningRBIID,GameWinningRBIName,VisitorStartingPitcherID,VisitorStartingPitcherName,HomeStartingPitcherID,HomeStartingPitcherName,VisitorBatting1PlayerID,VisitorBatting1Name,VisitorBatting1Position,VisitorBatting2PlayerID,VisitorBatting2Name,VisitorBatting2Position,VisitorBatting3PlayerID,VisitorBatting3Name,VisitorBatting3Position,VisitorBatting4PlayerID,VisitorBatting4Name,VisitorBatting4Position,VisitorBatting5PlayerID,VisitorBatting5Name,VisitorBatting5Position,VisitorBatting6PlayerID,VisitorBatting6Name,VisitorBatting6Position,VisitorBatting7PlayerID,VisitorBatting7Name,VisitorBatting7Position,VisitorBatting8PlayerID,VisitorBatting8Name,VisitorBatting8Position,VisitorBatting9PlayerID,VisitorBatting9Name,VisitorBatting9Position,HomeBatting1PlayerID,HomeBatting1Name,HomeBatting1Position,HomeBatting2PlayerID,HomeBatting2Name,HomeBatting2Position,HomeBatting3PlayerID,HomeBatting3Name,HomeBatting3Position,HomeBatting4PlayerID,HomeBatting4Name,HomeBatting4Position,HomeBatting5PlayerID,HomeBatting5Name,HomeBatting5Position,HomeBatting6PlayerID,HomeBatting6Name,HomeBatting6Position,HomeBatting7PlayerID,HomeBatting7Name,HomeBatting7Position,HomeBatting8PlayerID,HomeBatting8Name,HomeBatting8Position,HomeBatting9PlayerID,HomeBatting9Name,HomeBatting9Position,AdditionalInfo,AcquisitionInfo"

# %%
lst = lst.split(",")

# %%
file = '/Users/Lisa/_MLB_Prediction_capstone/data/Retrosheet_2010_2019/retrosheet_season_data/GL2010.TXT'

# %%
df = pd.read_csv(file, names=lst)

# %%
col_to_drop_1 = ['DoubleHeader', 'DayOfWeek', 'VisitingTeamLeague', 'HomeTeamLeague', 'VisitingTeamGameNumber',
                'HomeTeamGameNumber', 'VisitorRunsScored', 'HomeRunsScore', 'LengthInOuts', 'DayNight', 
                'CompletionInfo', 'ForfeitInfo', 'ProtestInfo', 'ParkID', 'Attendence', 'Duration',
                'VisitorLineScore', 'HomeLineScore', 'VisitorCI', 'HomeCI', 'UmpireHID',
                 'UmpireHName', 'Umpire1BID', 'Umpire1BName','Umpire2BID', 'Umpire2BName','Umpire3BID','Umpire3BName','UmpireLFID',
                 'UmpireLFName','UmpireRFID','UmpireRFName','VisitorManagerID',
                'VisitorManagerName','HomeManagerID','HomeManagerName','WinningPitcherID',
                 'WinningPitcherName','LosingPitcherID','LosingPitcherNAme','SavingPitcherID',
                 'SavingPitcherName', 'GameWinningRBIID', 'GameWinningRBIName', 'AdditionalInfo', 
                 'AcquisitionInfo']

# %%
len(col_to_drop_1)
# Out:
# 46

# %%
df
# Out:
#           Date  DoubleHeader DayOfWeek VisitingTeam VisitingTeamLeague  \
# 0     20100404             0       Sun          NYA                 AL
# 1     20100405             0       Mon          MIN                 AL
# 2     20100405             0       Mon          CLE                 AL
# 3     20100405             0       Mon          DET                 AL
# 4     20100405             0       Mon          SEA                 AL
# ...        ...           ...       ...          ...                ...
# 2425  20101003             0       Sun          CHN                 NL
# 2426  20101003             0       Sun          ARI                 NL
# 2427  20101003             0       Sun          WAS                 NL
# 2428  20101003             0       Sun          SDN                 NL
# 2429  20101003             0       Sun          COL                 NL
#
#       VisitingTeamGameNumber HomeTeam HomeTeamLeague  HomeTeamGameNumber  \
# 0                          1      BOS             AL                   1
# 1                          1      ANA             AL                   1
# 2                          1      CHA             AL                   1
# 3                          1      KCA             AL                   1
# 4                          1      OAK             AL                   1
# ...                      ...      ...            ...                 ...
# 2425                     162      HOU             NL                 162
# 2426                     162      LAN             NL                 162
# 2427                     162      NYN             NL                 162
# 2428                     162      SFN             NL                 162
# 2429                     162      SLN             NL                 162
#
#       VisitorRunsScored  ...     HomeBatting7Name  HomeBatting7Position  \
# 0                     7  ...            J.D. Drew                     9
# 1                     3  ...       Howie Kendrick                     4
# 2                     0  ...      A.J. Pierzynski                     2
# 3                     8  ...  Yuniesky Betancourt                     6
# 4                     5  ...           Mark Ellis                     4
# ...                 ...  ...                  ...                   ...
# 2425                  0  ...    Humberto Quintero                     2
# 2426                  1  ...          Brad Ausmus                     2
# 2427                  2  ...           Josh Thole                     2
# 2428                  0  ...         Jose Guillen                     9
# 2429                  1  ...        Matt Pagnozzi                     2
#
#      HomeBatting8PlayerID HomeBatting8Name  HomeBatting8Position  \
# 0                camem001     Mike Cameron                     8
# 1                woodb003     Brandon Wood                     5
# 2                teahm001      Mark Teahen                     5
# 3                kendj001    Jason Kendall                     2
# 4                buckt001      Travis Buck                     7
# ...                   ...              ...                   ...
# 2425             manzt001   Tommy Manzella                     6
# 2426             johnr008     Reed Johnson                     7
# 2427             tejar001     Ruben Tejada                     4
# 2428             sandp001   Pablo Sandoval                     5
# 2429             ryanb002     Brendan Ryan                     6
#
#      HomeBatting9PlayerID  HomeBatting9Name  HomeBatting9Position  \
# 0                scutm001     Marco Scutaro                     6
# 1                mathj001       Jeff Mathis                     2
# 2                ramia003    Alexei Ramirez                     6
# 3                getzc001        Chris Getz                     4
# 4                pennc001  Cliff Pennington                     6
# ...                   ...               ...                   ...
# 2425             figun001   Nelson Figueroa                     1
# 2426             lillt001         Ted Lilly                     1
# 2427             pelfm001      Mike Pelfrey                     1
# 2428             sancj002  Jonathan Sanchez                     1
# 2429             suppj001       Jeff Suppan                     1
#
#       AdditionalInfo AcquisitionInfo
# 0                NaN               Y
# 1                NaN               Y
# 2                NaN               Y
# 3                NaN               Y
# 4                NaN               Y
# ...              ...             ...
# 2425             NaN               Y
# 2426             NaN               Y
# 2427             NaN               Y
# 2428             NaN               Y
# 2429             NaN               Y
#
# [2430 rows x 161 columns]

# %%
df.iloc[:, 0:20]
# Out:
#           Date  DoubleHeader DayOfWeek VisitingTeam VisitingTeamLeague  \
# 0     20100404             0       Sun          NYA                 AL
# 1     20100405             0       Mon          MIN                 AL
# 2     20100405             0       Mon          CLE                 AL
# 3     20100405             0       Mon          DET                 AL
# 4     20100405             0       Mon          SEA                 AL
# ...        ...           ...       ...          ...                ...
# 2425  20101003             0       Sun          CHN                 NL
# 2426  20101003             0       Sun          ARI                 NL
# 2427  20101003             0       Sun          WAS                 NL
# 2428  20101003             0       Sun          SDN                 NL
# 2429  20101003             0       Sun          COL                 NL
#
#       VisitingTeamGameNumber HomeTeam HomeTeamLeague  HomeTeamGameNumber  \
# 0                          1      BOS             AL                   1
# 1                          1      ANA             AL                   1
# 2                          1      CHA             AL                   1
# 3                          1      KCA             AL                   1
# 4                          1      OAK             AL                   1
# ...                      ...      ...            ...                 ...
# 2425                     162      HOU             NL                 162
# 2426                     162      LAN             NL                 162
# 2427                     162      NYN             NL                 162
# 2428                     162      SFN             NL                 162
# 2429                     162      SLN             NL                 162
#
#       VisitorRunsScored  HomeRunsScore  LengthInOuts DayNight CompletionInfo  \
# 0                     7              9            51        N            NaN
# 1                     3              6            51        N            NaN
# 2                     0              6            51        D            NaN
# 3                     8              4            54        D            NaN
# 4                     5              3            54        N            NaN
# ...                 ...            ...           ...      ...            ...
# 2425                  0              4            51        D            NaN
# 2426                  1              3            51        D            NaN
# 2427                  2              1            84        D            NaN
# 2428                  0              3            51        D            NaN
# 2429                  1              6            51        D            NaN
#
#       ForfeitInfo ProtestInfo ParkID  Attendence  Duration VisitorLineScore
# 0             NaN         NaN  BOS07       37440       226        020300200
# 1             NaN         NaN  ANA01       43504       180        020010000
# 2             NaN         NaN  CHI12       38935       144        000000000
# 3             NaN         NaN  KAN06       40052       185        100001600
# 4             NaN         NaN  OAK01       30686       167        111000002
# ...           ...         ...    ...         ...       ...              ...
# 2425          NaN         NaN  HOU03       31105       155        000000000
# 2426          NaN         NaN  LOS03       38007       166        000100000
# 2427          NaN         NaN  NYC20       30849       254   00001000000001
# 2428          NaN         NaN  SFO03       42822       185        000000000
# 2429          NaN         NaN  STL10       42409       153        000000010
#
# [2430 rows x 20 columns]

# %%
df.iloc[:, 20:40]
# Out:
#        HomeLineScore  VisitorAB  VisitorH  VisitorD  VisitorT  VisitorHR  \
# 0          01001331x         37        12         2         0          2
# 1          21001002x         32         7         1         0          1
# 2          20201001x         30         4         0         0          0
# 3          020020000         39        12         4         0          0
# 4          000001200         31         6         2         0          1
# ...              ...        ...       ...       ...       ...        ...
# 2425       02110000x         33         6         1         0          0
# 2426       20000010x         30         4         1         0          0
# 2427  00001000000000         46         6         2         0          0
# 2428       00200001x         30         4         0         0          0
# 2429       00220110x         32         7         1         1          1
#
#       VisitorRBI  VisitorSH  VisitorSF  VisitorHBP  VisitorBB  VisitorIBB  \
# 0              6          0          0           0          6           0
# 1              3          0          1           1          3           0
# 2              0          0          0           0          1           0
# 3              7          0          0           0          2           0
# 4              5          0          1           0          8           1
# ...          ...        ...        ...         ...        ...         ...
# 2425           0          0          0           0          3           1
# 2426           1          1          0           0          3           0
# 2427           2          0          0           1          6           0
# 2428           0          1          0           0          5           1
# 2429           1          0          0           0          1           0
#
#       VisitorK  VisitorSB  VisitorCS  VisitorGDP  VisitorCI  VisitorLOB  \
# 0            2          2          0           2          0           9
# 1            8          1          0           1          0           7
# 2            7          0          0           1          0           4
# 3            9          0          0           1          0           6
# 4            8          3          2           1          0           8
# ...        ...        ...        ...         ...        ...         ...
# 2425        12          0          0           0          0           9
# 2426        12          2          0           0          0           6
# 2427        12          1          0           2          0           9
# 2428        10          0          0           1          0           9
# 2429         9          0          1           0          0           5
#
#       VisitorPitchers  VisitorER
# 0                   5          8
# 1                   4          6
# 2                   4          6
# 3                   5          4
# 4                   4          3
# ...               ...        ...
# 2425                4          3
# 2426                5          3
# 2427                6          1
# 2428                5          3
# 2429                4          4
#
# [2430 rows x 20 columns]

# %%
df.iloc[:, 40:60]
# Out:
#       VisitorTER  VisitorWP  VisitorBalks  VisitorPO  VisitorA  VisitorE  \
# 0              8          1             0         24         9         1
# 1              6          1             0         24         4         0
# 2              6          4             0         24        14         0
# 3              4          0             0         27        12         1
# 4              3          1             0         27        18         1
# ...          ...        ...           ...        ...       ...       ...
# 2425           3          0             0         24         6         1
# 2426           3          0             0         24        10         1
# 2427           1          0             0         42        16         1
# 2428           3          1             0         24         8         0
# 2429           4          1             1         24        11         3
#
#       VisitorPassed  VisitorDB  VisitorTP  HomeAB  HomeH  HomeD  HomeT  \
# 0                 1          1          0      34     12      3      1
# 1                 0          0          0      33      9      0      0
# 2                 0          1          0      28      6      2      0
# 3                 0          0          0      35      9      0      0
# 4                 0          4          0      28      5      0      0
# ...             ...        ...        ...     ...    ...    ...    ...
# 2425              0          1          0      31      9      0      1
# 2426              0          2          0      29      8      1      0
# 2427              0          1          0      46      8      1      0
# 2428              0          1          0      34     11      1      1
# 2429              0          1          0      36     11      2      0
#
#       HomeHR  HomeRBI  HomeSH  HomeSF  HomeHBP  HomeBB  HomeIBB
# 0          1        8       0       1        0       4        0
# 1          3        6       0       0        0       3        0
# 2          2        4       0       0        2       5        0
# 3          1        4       1       0        0       2        0
# 4          0        3       0       0        0       7        0
# ...      ...      ...     ...     ...      ...     ...      ...
# 2425       1        3       1       0        0       2        0
# 2426       1        3       1       0        1       5        1
# 2427       0        0       3       0        1       3        1
# 2428       1        3       0       0        0       1        0
# 2429       0        4       0       0        0       2        0
#
# [2430 rows x 20 columns]

# %%
df.iloc[:, 60:80]
# Out:
#       HomeK  HomeSB  HomeCS  HomeGDP  HomeCI  HomeLOB  HomePitchers  HomeER  \
# 0         5       0       0        0       0        6             6       7
# 1         5       1       0        0       0        6             4       3
# 2         4       0       1        1       0        5             3       0
# 3         8       2       0        0       0        7             6       7
# 4         6       1       0        4       0        5             5       2
# ...     ...     ...     ...      ...     ...      ...           ...     ...
# 2425     10       1       0        1       0        6             4       0
# 2426      6       0       0        1       0        9             3       1
# 2427      7       0       1        1       0       10             7       2
# 2428      4       0       0        1       0        8             6       0
# 2429      4       0       0        1       0        8             3       1
#
#       HomeTER  HomeWP  HomeBalks  HomePO  HomeA  HomeE  HomePassed  HomeDB  \
# 0           7       1          0      27     15      0           0       2
# 1           3       0          0      27     10      0           0       1
# 2           0       0          0      27      9      0           0       1
# 3           7       0          0      27      9      1           0       1
# 4           2       1          0      27      9      4           0       1
# ...       ...     ...        ...     ...    ...    ...         ...     ...
# 2425        0       0          0      27      8      0           0       0
# 2426        1       0          0      27      7      0           0       0
# 2427        2       0          0      42     14      0           0       2
# 2428        0       0          0      27     12      1           0       1
# 2429        1       1          0      27      8      0           0       1
#
#       HomeTP UmpireHID      UmpireHName Umpire1BID
# 0          0  westj901         Joe West   herna901
# 1          0  mcclt901   Tim McClelland   everm901
# 2          0  darlg901     Gary Darling   hohnb901
# 3          0  rapue901       Ed Rapuano   culbf901
# 4          0  tscht901      Tim Tschida   davib902
# ...      ...       ...              ...        ...
# 2425       0  davib902     Bob Davidson   timmt901
# 2426       0  marqa901  Alfonso Marquez   knigb901
# 2427       0  estam901   Mike Estabrook   kellj901
# 2428       0  mcclt901   Tim McClelland   johna901
# 2429       0  kulpr901        Ron Kulpa   culbf901
#
# [2430 rows x 20 columns]

# %%
df.iloc[:, 80:100]
# Out:
#           Umpire1BName Umpire2BID     Umpire2BName Umpire3BID  \
# 0      Angel Hernandez   schrp901   Paul Schrieber   drakr901
# 1         Mike Everitt   fleta901    Andy Fletcher   johna901
# 2            Bill Hohn   drecb901   Bruce Dreckman   estam901
# 3     Fieldin Culbreth   kulpr901        Ron Kulpa   barkl901
# 4         Bob Davidson   marqa901  Alfonso Marquez   muchm901
# ...                ...        ...              ...        ...
# 2425       Tim Timmons   rackd901    David Rackley   barrl901
# 2426      Brian Knight   gibsg901      Greg Gibson   davig901
# 2427      Jeff Kellogg   vanol901    Larry Vanover   carlm901
# 2428    Adrian Johnson   fleta901    Andy Fletcher   everm901
# 2429  Fieldin Culbreth   cedeg901  Gary Cederstrom   hicke901
#
#          Umpire3BName  UmpireLFID UmpireLFName  UmpireRFID UmpireRFName  \
# 0           Rob Drake         NaN       (none)         NaN       (none)
# 1      Adrian Johnson         NaN       (none)         NaN       (none)
# 2      Mike Estabrook         NaN       (none)         NaN       (none)
# 3     Lance Barksdale         NaN       (none)         NaN       (none)
# 4     Mike Muchlinski         NaN       (none)         NaN       (none)
# ...               ...         ...          ...         ...          ...
# 2425    Lance Barrett         NaN       (none)         NaN       (none)
# 2426      Gerry Davis         NaN       (none)         NaN       (none)
# 2427     Mark Carlson         NaN       (none)         NaN       (none)
# 2428     Mike Everitt         NaN       (none)         NaN       (none)
# 2429        Ed Hickox         NaN       (none)         NaN       (none)
#
#      VisitorManagerID VisitorManagerName HomeManagerID HomeManagerName  \
# 0            giraj001        Joe Girardi      frant001  Terry Francona
# 1            gardr001     Ron Gardenhire      sciom001   Mike Scioscia
# 2            actam801         Manny Acta      guilo001   Ozzie Guillen
# 3            leylj801        Jim Leyland      hillt801    Trey Hillman
# 4            wakad001      Don Wakamatsu      gereb001       Bob Geren
# ...               ...                ...           ...             ...
# 2425         quadm801         Mike Quade      millb101      Brad Mills
# 2426         gibsk001        Kirk Gibson      torrj101       Joe Torre
# 2427         riggj801      Jim Riggleman      manuj101    Jerry Manuel
# 2428         blacb001        Buddy Black      bochb002     Bruce Bochy
# 2429         tracj101          Jim Tracy      larut101    Tony LaRussa
#
#      WinningPitcherID WinningPitcherName LosingPitcherID LosingPitcherNAme  \
# 0            okajh001     Hideki Okajima        parkc002      Chan Ho Park
# 1            weavj003       Jered Weaver        bakes002       Scott Baker
# 2            buehm001       Mark Buehrle        westj001    Jake Westbrook
# 3            zumaj001        Joel Zumaya        tejer001        Rob Tejeda
# 4            leagb001     Brandon League        ziegb001      Brad Ziegler
# ...               ...                ...             ...               ...
# 2425         figun001    Nelson Figueroa        dempr002     Ryan Dempster
# 2426         lillt001          Ted Lilly        loper001     Rodrigo Lopez
# 2427         peraj002       Joel Peralta        pereo002      Oliver Perez
# 2428         sancj002   Jonathan Sanchez        latom001         Mat Latos
# 2429         suppj001        Jeff Suppan        rogee002      Esmil Rogers
#
#      SavingPitcherID  SavingPitcherName GameWinningRBIID
# 0           papej001  Jonathan Papelbon              NaN
# 1           fuenb001      Brian Fuentes         matsh001
# 2                NaN             (none)         konep001
# 3                NaN             (none)         damoj001
# 4           aardd001      David Aardsma         kotcc001
# ...              ...                ...              ...
# 2425             NaN             (none)         manzt001
# 2426        kuo-h001      Hong-Chih Kuo         kempm001
# 2427        batim001     Miguel Batista         maxwj002
# 2428        wilsb001       Brian Wilson         sancf001
# 2429             NaN             (none)              NaN
#
# [2430 rows x 20 columns]

# %%
df.iloc[:, 100:120]
# Out:
#      GameWinningRBIName VisitorStartingPitcherID VisitorStartingPitcherName  \
# 0                (none)                 sabac001                CC Sabathia
# 1         Hideki Matsui                 bakes002                Scott Baker
# 2          Paul Konerko                 westj001             Jake Westbrook
# 3          Johnny Damon                 verlj001           Justin Verlander
# 4        Casey Kotchman                 hernf002            Felix Hernandez
# ...                 ...                      ...                        ...
# 2425     Tommy Manzella                 dempr002              Ryan Dempster
# 2426          Matt Kemp                 loper001              Rodrigo Lopez
# 2427     Justin Maxwell                 hernl003            Livan Hernandez
# 2428     Freddy Sanchez                 latom001                  Mat Latos
# 2429             (none)                 rogee002               Esmil Rogers
#
#      HomeStartingPitcherID HomeStartingPitcherName VisitorBatting1PlayerID  \
# 0                 beckj002            Josh Beckett                jeted001
# 1                 weavj003            Jered Weaver                spand001
# 2                 buehm001            Mark Buehrle                cabra002
# 3                 greiz001            Zack Greinke                jacka001
# 4                 sheeb001              Ben Sheets                suzui001
# ...                    ...                     ...                     ...
# 2425              figun001         Nelson Figueroa                dewib001
# 2426              lillt001               Ted Lilly                abret001
# 2427              pelfm001            Mike Pelfrey                espid001
# 2428              sancj002        Jonathan Sanchez                denoc001
# 2429              suppj001             Jeff Suppan                fowld001
#
#      VisitorBatting1Name  VisitorBatting1Position VisitorBatting2PlayerID  \
# 0            Derek Jeter                        6                johnn001
# 1            Denard Span                        8                hudso001
# 2       Asdrubal Cabrera                        6                sizeg001
# 3         Austin Jackson                        8                damoj001
# 4          Ichiro Suzuki                        9                figgc001
# ...                  ...                      ...                     ...
# 2425        Blake DeWitt                        4                barnd001
# 2426          Tony Abreu                        5                ojeda001
# 2427      Danny Espinosa                        4                morgn001
# 2428      Chris Denorfia                        8                ecksd001
# 2429       Dexter Fowler                        8                barmc001
#
#      VisitorBatting2Name  VisitorBatting2Position VisitorBatting3PlayerID  \
# 0           Nick Johnson                       10                teixm001
# 1         Orlando Hudson                        4                mauej001
# 2         Grady Sizemore                        8                choos001
# 3           Johnny Damon                        7                ordom001
# 4          Chone Figgins                        4                kotcc001
# ...                  ...                      ...                     ...
# 2425       Darwin Barney                        6                byrdm001
# 2426         Augie Ojeda                        6                ryalr001
# 2427        Nyjer Morgan                        8                desmi001
# 2428      David Eckstein                        4                tejam001
# 2429        Clint Barmes                        6                mckem001
#
#      VisitorBatting3Name  VisitorBatting3Position VisitorBatting4PlayerID  \
# 0          Mark Teixeira                        3                rodra001
# 1              Joe Mauer                        2                mornj001
# 2          Shin-Soo Choo                        9                hafnt001
# 3        Magglio Ordonez                        9                cabrm001
# 4         Casey Kotchman                        3                bradm001
# ...                  ...                      ...                     ...
# 2425         Marlon Byrd                        8                ramia001
# 2426          Rusty Ryal                        3                alleb001
# 2427         Ian Desmond                        6                dunna001
# 2428       Miguel Tejada                        6                gonza003
# 2429     Michael McKenry                        2                stewi001
#
#      VisitorBatting4Name  VisitorBatting4Position VisitorBatting5PlayerID  \
# 0         Alex Rodriguez                        5                canor001
# 1         Justin Morneau                        3                cuddm001
# 2          Travis Hafner                       10                peraj001
# 3         Miguel Cabrera                        3                guilc001
# 4         Milton Bradley                        7                grifk002
# ...                  ...                      ...                     ...
# 2425      Aramis Ramirez                        5                nadyx001
# 2426       Brandon Allen                        7                rober002
# 2427           Adam Dunn                        3                bernr001
# 2428     Adrian Gonzalez                        3                ludwr001
# 2429         Ian Stewart                        5                iannc001
#
#      VisitorBatting5Name  VisitorBatting5Position
# 0          Robinson Cano                        4
# 1        Michael Cuddyer                        9
# 2         Jhonny Peralta                        5
# 3         Carlos Guillen                       10
# 4            Ken Griffey                       10
# ...                  ...                      ...
# 2425         Xavier Nady                        3
# 2426        Ryan Roberts                        4
# 2427     Roger Bernadina                        7
# 2428        Ryan Ludwick                        9
# 2429      Chris Iannetta                        3
#
# [2430 rows x 20 columns]

# %%
df.iloc[:, 120:140]
# Out:
#      VisitorBatting6PlayerID VisitorBatting6Name  VisitorBatting6Position  \
# 0                   posaj001        Jorge Posada                        2
# 1                   kubej002         Jason Kubel                       10
# 2                   lapom001        Matt LaPorta                        3
# 3                   ingeb001        Brandon Inge                        5
# 4                   lopej003          Jose Lopez                        5
# ...                      ...                 ...                      ...
# 2425                soria001     Alfonso Soriano                        7
# 2426                parrg001       Gerardo Parra                        9
# 2427                rodri001      Ivan Rodriguez                        2
# 2428                torry001    Yorvit Torrealba                        2
# 2429                smits002          Seth Smith                        9
#
#      VisitorBatting7PlayerID VisitorBatting7Name  VisitorBatting7Position  \
# 0                   granc001   Curtis Granderson                        8
# 1                   yound003        Delmon Young                        7
# 2                   grudm001   Mark Grudzielanek                        4
# 3                   lairg001        Gerald Laird                        2
# 4                   gutif001  Franklin Gutierrez                        8
# ...                      ...                 ...                      ...
# 2425                snydb002         Brad Snyder                        9
# 2426                schmk001      Konrad Schmidt                        2
# 2427                harrw001       Willie Harris                        9
# 2428                hairs001      Scott Hairston                        7
# 2429                paytj001          Jay Payton                        7
#
#      VisitorBatting8PlayerID VisitorBatting8Name  VisitorBatting8Position  \
# 0                   swisn001        Nick Swisher                        9
# 1                   hardj003          J.J. Hardy                        6
# 2                   marsl001          Lou Marson                        2
# 3                   sizes001      Scott Sizemore                        4
# 4                   johnr009         Rob Johnson                        2
# ...                      ...                 ...                      ...
# 2425                hillk002          Koyie Hill                        2
# 2426                gillc002      Cole Gillespie                        8
# 2427                gonza005    Alberto Gonzalez                        5
# 2428                headc001       Chase Headley                        5
# 2429                nelsc001        Chris Nelson                        4
#
#      VisitorBatting9PlayerID VisitorBatting9Name  VisitorBatting9Position  \
# 0                   gardb001       Brett Gardner                        7
# 1                   puntn001          Nick Punto                        5
# 2                   branm003    Michael Brantley                        7
# 3                   evera001        Adam Everett                        6
# 4                   wilsj002         Jack Wilson                        6
# ...                      ...                 ...                      ...
# 2425                dempr002       Ryan Dempster                        1
# 2426                loper001       Rodrigo Lopez                        1
# 2427                hernl003     Livan Hernandez                        1
# 2428                latom001           Mat Latos                        1
# 2429                rogee002        Esmil Rogers                        1
#
#      HomeBatting1PlayerID HomeBatting1Name  HomeBatting1Position  \
# 0                ellsj001  Jacoby Ellsbury                     7
# 1                aybae001      Erick Aybar                     6
# 2                pierj002      Juan Pierre                     7
# 3                dejed001    David DeJesus                     9
# 4                davir003      Rajai Davis                     8
# ...                   ...              ...                   ...
# 2425             bogub001  Brian Bogusevic                     8
# 2426             furcr001    Rafael Furcal                     6
# 2427             reyej001       Jose Reyes                     6
# 2428             torra001    Andres Torres                     8
# 2429             schus001   Skip Schumaker                     4
#
#      HomeBatting2PlayerID HomeBatting2Name  HomeBatting2Position  \
# 0                pedrd001   Dustin Pedroia                     4
# 1                abreb001      Bobby Abreu                     9
# 2                beckg001   Gordon Beckham                     4
# 3                podss001  Scott Podsednik                     7
# 4                bartd001     Daric Barton                     3
# ...                   ...              ...                   ...
# 2425             keppj001   Jeff Keppinger                     4
# 2426             carrj001    Jamey Carroll                     4
# 2427             felij002  Jesus Feliciano                     9
# 2428             sancf001   Freddy Sanchez                     4
# 2429             winnr001       Randy Winn                     9
#
#      HomeBatting3PlayerID HomeBatting3Name
# 0                martv001  Victor Martinez
# 1                huntt001     Torii Hunter
# 2                quenc001   Carlos Quentin
# 3                butlb003     Billy Butler
# 4                sweer001     Ryan Sweeney
# ...                   ...              ...
# 2425             pench001     Hunter Pence
# 2426             ethia001     Andre Ethier
# 2427             wrigd002     David Wright
# 2428             huffa001      Aubrey Huff
# 2429             pujoa001    Albert Pujols
#
# [2430 rows x 20 columns]

# %%
df.iloc[:, 140:160]
# Out:
#       HomeBatting3Position HomeBatting4PlayerID  HomeBatting4Name  \
# 0                        2             youkk001    Kevin Youkilis
# 1                        8             matsh001     Hideki Matsui
# 2                        9             konep001      Paul Konerko
# 3                        3             ankir001       Rick Ankiel
# 4                        9             kouzk001  Kevin Kouzmanoff
# ...                    ...                  ...               ...
# 2425                     9             lee-c001        Carlos Lee
# 2426                     9             kempm001         Matt Kemp
# 2427                     5             davii001         Ike Davis
# 2428                     3             poseb001      Buster Posey
# 2429                     3             hollm001     Matt Holliday
#
#       HomeBatting4Position HomeBatting5PlayerID HomeBatting5Name  \
# 0                        3             ortid001      David Ortiz
# 1                       10             morak001  Kendrys Morales
# 2                        3             kotsm001      Mark Kotsay
# 3                        8             guilj001     Jose Guillen
# 4                        5             suzuk001      Kurt Suzuki
# ...                    ...                  ...              ...
# 2425                     7             johnc003    Chris Johnson
# 2426                     8             lonej001      James Loney
# 2427                     3             pagaa001      Angel Pagan
# 2428                     2             burrp001      Pat Burrell
# 2429                     7             rasmc001     Colby Rasmus
#
#       HomeBatting5Position HomeBatting6PlayerID   HomeBatting6Name  \
# 0                       10             belta001      Adrian Beltre
# 1                        3             rivej001        Juan Rivera
# 2                       10             riosa002          Alex Rios
# 3                       10             bloow001  Willie Bloomquist
# 4                        2             chave001        Eric Chavez
# ...                    ...                  ...                ...
# 2425                     5             wallb001      Brett Wallace
# 2426                     3             blakc001        Casey Blake
# 2427                     8             dudal001         Lucas Duda
# 2428                     7             uribj002         Juan Uribe
# 2429                     8             descd001    Daniel Descalso
#
#       HomeBatting6Position HomeBatting7PlayerID     HomeBatting7Name  \
# 0                        5             drewj001            J.D. Drew
# 1                        7             kendh001       Howie Kendrick
# 2                        8             piera001      A.J. Pierzynski
# 3                        5             betay001  Yuniesky Betancourt
# 4                       10             ellim001           Mark Ellis
# ...                    ...                  ...                  ...
# 2425                     3             quinh001    Humberto Quintero
# 2426                     5             ausmb001          Brad Ausmus
# 2427                     7             tholj001           Josh Thole
# 2428                     6             guilj001         Jose Guillen
# 2429                     5             pagnm001        Matt Pagnozzi
#
#       HomeBatting7Position HomeBatting8PlayerID HomeBatting8Name  \
# 0                        9             camem001     Mike Cameron
# 1                        4             woodb003     Brandon Wood
# 2                        2             teahm001      Mark Teahen
# 3                        6             kendj001    Jason Kendall
# 4                        4             buckt001      Travis Buck
# ...                    ...                  ...              ...
# 2425                     2             manzt001   Tommy Manzella
# 2426                     2             johnr008     Reed Johnson
# 2427                     2             tejar001     Ruben Tejada
# 2428                     9             sandp001   Pablo Sandoval
# 2429                     2             ryanb002     Brendan Ryan
#
#       HomeBatting8Position HomeBatting9PlayerID  HomeBatting9Name  \
# 0                        8             scutm001     Marco Scutaro
# 1                        5             mathj001       Jeff Mathis
# 2                        5             ramia003    Alexei Ramirez
# 3                        2             getzc001        Chris Getz
# 4                        7             pennc001  Cliff Pennington
# ...                    ...                  ...               ...
# 2425                     6             figun001   Nelson Figueroa
# 2426                     7             lillt001         Ted Lilly
# 2427                     4             pelfm001      Mike Pelfrey
# 2428                     5             sancj002  Jonathan Sanchez
# 2429                     6             suppj001       Jeff Suppan
#
#       HomeBatting9Position AdditionalInfo
# 0                        6            NaN
# 1                        2            NaN
# 2                        6            NaN
# 3                        4            NaN
# 4                        6            NaN
# ...                    ...            ...
# 2425                     1            NaN
# 2426                     1            NaN
# 2427                     1            NaN
# 2428                     1            NaN
# 2429                     1            NaN
#
# [2430 rows x 20 columns]

# %%
df.iloc[:, 160:]
# Out:
#      AcquisitionInfo
# 0                  Y
# 1                  Y
# 2                  Y
# 3                  Y
# 4                  Y
# ...              ...
# 2425               Y
# 2426               Y
# 2427               Y
# 2428               Y
# 2429               Y
#
# [2430 rows x 1 columns]
